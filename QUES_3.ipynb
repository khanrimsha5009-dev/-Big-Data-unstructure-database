# %% [markdown]
# <a href="https://colab.research.google.com/github/khanrimsha5009-dev/-Big-Data-unstructure-database/blob/main/QUES_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1=Warisha - Meaning of the Name (BabyNamesPedia)
   https://www.babynamespedia.com/meaning/Warisha
   Meaning: Arabic-origin girl's name, often interpreted as "lightning".
   Source: :contentReference[oaicite:0]{index=0}


2="Warisha" Profiles (LinkedIn)
   Professional profiles of people named Warisha worldwide.
   Source: :contentReference[oaicite:1]{index=1}

3= Warisha -  Girl Name Meaning (NamesBloom)
   Meaning: "Light, Ray" with Arabic origin.
   Source: :contentReference[oaicite:2]{index=2}

4= Warisha: Meaning, Origin, Traits & More (Namedary)
   Discussion of the name's origin and popularity.
   Source: :contentReference[oaicite:3]{index=3}
